# %% [markdown]
# By using triple-quoted strings (either """ or ''') that are not assigned to a variable. When unassigned, these string literals are ignored by the interpreter, effectively acting as comments. This method is often used for writing docstrings, which are a special type of documentation for functions, classes, and modules.

# %%
#comments in python
""" This
is 
a
Multiline
comment"""

print('For Single line comments in python # is used')
# Out:
# For Single line comments in python # is used

# %% [markdown]
# ### Print Without a New Line
# By default, the print() function ends with a new line.
#
# If you want to print multiple words on the same line, you can use the end parameter:

# %%
print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World! I will print on the same line.
